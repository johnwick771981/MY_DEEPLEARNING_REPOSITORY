# %% [markdown]
# # LOADING DATA FROM CSV FILE

# %% [markdown]
# 1. THE PANDAS LIBRARY IN PYTHON PROVIDES EXCELLENT BUILT IN SUPPORT FOR TIME SERIES DATA
# 2. PANDAS REPRESENTS TIME SERIES DATA A SERIES
# 3. A SERIES IS A 1-D ARRAY WITH A TIME LABEL FOR EACH ROW
# 4. A DATAFRAME IS A COLLECTION OF SERIES

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("C:/Data Files/Time Series/daily-total-female-births-CA.csv" , header=0)

# %%
dataframe.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
dataframe['date'].dtype
# Out:
# dtype('O')

# %%
df2 = pd.read_csv("C:/Data Files/Time Series/daily-total-female-births-CA.csv" , header=0 , parse_dates=[0])

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df2['date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# USE dateparse = lambda X pd.datetime.strptime(X . '%Y-%m-%d %H %M %S')

# %%
series = pd.read_csv("C:/Data Files/Time Series/daily-total-female-births-CA.csv" , header=0 , parse_dates=[0] , index_col=0 , squeeze= True)

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
series.shape
# Out:
# (365,)

# %%
df2.shape
# Out:
# (365, 2)

# %%
print(series['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df2[(df2['date'] > '1959-01-01') & (df2['date'] <= '1959-01-21')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34

# %%
series.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: births, dtype: float64

# %%
df2.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
dataviz_df = df2.copy()

# %%
dataviz_df.head(10)
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44
# 5 1959-01-06      29
# 6 1959-01-07      45
# 7 1959-01-08      43
# 8 1959-01-09      38
# 9 1959-01-10      27

# %%
dataviz_df['births'].plot()
# Out:
# <AxesSubplot:>

# %%
dataviz_df.index = dataviz_df['date']

# %%
dataviz_df['births']
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
#               ..
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: births, Length: 365, dtype: int64

# %%
dataviz_df['births'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # ZOOMING IN

# %%
dataviz_df2 = dataviz_df[(dataviz_df['date'] > '1959-01-01') & (dataviz_df['date'] <= '1959-01-10')].copy()

# %%
dataviz_df2
# Out:
#                  date  births
# date
# 1959-01-02 1959-01-02      32
# 1959-01-03 1959-01-03      30
# 1959-01-04 1959-01-04      31
# 1959-01-05 1959-01-05      44
# 1959-01-06 1959-01-06      29
# 1959-01-07 1959-01-07      45
# 1959-01-08 1959-01-08      43
# 1959-01-09 1959-01-09      38
# 1959-01-10 1959-01-10      27

# %%
dataviz_df2['births'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # TRENDLINE

# %%
import seaborn as sns

# %%
sns.regplot(x = df2.index.values , y=df2['births'])
# Out:
# <AxesSubplot:ylabel='births'>

# %%
sns.regplot(x = df2.index.values , y=df2['births'] , order =2)
# Out:
# <AxesSubplot:ylabel='births'>

# %% [markdown]
# #  MILES AIRLINE DATASET

# %%
miles_df = pd.read_csv("C:/Data Files/Time Series/us-airlines-monthly-aircraft-miles-flown.csv" , header=0 , parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_df["MilesMM"].plot()
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x=miles_df.index.values , y= miles_df['MilesMM'])
# Out:
# <AxesSubplot:ylabel='MilesMM'>

# %% [markdown]
# # REMOVING SEASONALITY

# %%
miles_df['year']  = miles_df['Month'].dt.year

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year
# 0 1963-01-01     6827  1963
# 1 1963-02-01     6178  1963
# 2 1963-03-01     7084  1963
# 3 1963-04-01     8162  1963
# 4 1963-05-01     8462  1963

# %%
miles_df.groupby('year')["MilesMM"].mean()
# Out:
# year
# 1963     8300.250000
# 1964     8849.333333
# 1965     9619.250000
# 1966     9929.500000
# 1967    10542.916667
# 1968    10747.916667
# 1969    11972.000000
# 1970    13124.750000
# Name: MilesMM, dtype: float64

# %%
miles_df.groupby('year')["MilesMM"].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # CREATING LAG PLOTS

# %%
miles_df['lag1']  = miles_df["MilesMM"].shift(1)

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year    lag1
# 0 1963-01-01     6827  1963     NaN
# 1 1963-02-01     6178  1963  6827.0
# 2 1963-03-01     7084  1963  6178.0
# 3 1963-04-01     8162  1963  7084.0
# 4 1963-05-01     8462  1963  8162.0

# %%
sns.scatterplot(x= miles_df['lag1']  , y=miles_df["MilesMM"])
# Out:
# <AxesSubplot:xlabel='lag1', ylabel='MilesMM'>

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(miles_df["MilesMM"])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# # AUTO-CORRELATION PLOTS

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(miles_df["MilesMM"])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# every six months we get a dip/increase , lows/highs

# %% [markdown]
# # FEATURE ENGINEERING OF FEMALE DATA

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
features = df2.copy()

# %%
features['year'] = df2['date'].dt.year

# %%
features['month'] = df2['date'].dt.month

# %%
features['day'] = df2['date'].dt.day

# %%
features.head(5)
# Out:
#         date  births  year  month  day
# 0 1959-01-01      35  1959      1    1
# 1 1959-01-02      32  1959      1    2
# 2 1959-01-03      30  1959      1    3
# 3 1959-01-04      31  1959      1    4
# 4 1959-01-05      44  1959      1    5

# %% [markdown]
# ### LAG FEATURES

# %%
features['lag1'] = df2['births'].shift(1)

# %%
features['lag2'] = df2['births'].shift(365)

# %%
features.head(5)
# Out:
#         date  births  year  month  day  lag1  lag2
# 0 1959-01-01      35  1959      1    1   NaN   NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN
# 3 1959-01-04      31  1959      1    4  30.0   NaN
# 4 1959-01-05      44  1959      1    5  31.0   NaN

# %% [markdown]
# ### WINDOW FEATURES

# %%
features['roll_mean']  = df2['births'].rolling(window = 2).mean()

# %%
features['roll_max']  = df2['births'].rolling(window = 3).max()

# %%
features.head()
# Out:
#         date  births  year  month  day  lag1  lag2  roll_mean  roll_max
# 0 1959-01-01      35  1959      1    1   NaN   NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0   NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0   NaN       37.5      44.0

# %% [markdown]
# ### EXPANDING FEATURES

# %%
features['expand_max']  = df2['births'].expanding().max()

# %%
features.head(10)
# Out:
#         date  births  year  month  day  lag1  lag2  roll_mean  roll_max  \
# 0 1959-01-01      35  1959      1    1   NaN   NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0   NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0   NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0   NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0   NaN       37.5      44.0
# 5 1959-01-06      29  1959      1    6  44.0   NaN       36.5      44.0
# 6 1959-01-07      45  1959      1    7  29.0   NaN       37.0      45.0
# 7 1959-01-08      43  1959      1    8  45.0   NaN       44.0      45.0
# 8 1959-01-09      38  1959      1    9  43.0   NaN       40.5      45.0
# 9 1959-01-10      27  1959      1   10  38.0   NaN       32.5      43.0
#
#    expand_max
# 0        35.0
# 1        35.0
# 2        35.0
# 3        35.0
# 4        44.0
# 5        44.0
# 6        45.0
# 7        45.0
# 8        45.0
# 9        45.0

# %% [markdown]
# ### DOWNSAMPLING AND UPSAMPLING

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year    lag1
# 0 1963-01-01     6827  1963     NaN
# 1 1963-02-01     6178  1963  6827.0
# 2 1963-03-01     7084  1963  6178.0
# 3 1963-04-01     8162  1963  7084.0
# 4 1963-05-01     8462  1963  8162.0

# %%
quarterly_miles_df = miles_df.resample('Q' , on='Month').mean()

# %%
quarterly_miles_df.head()
# Out:
#                  MilesMM    year          lag1
# Month
# 1963-03-31   6696.333333  1963.0   6502.500000
# 1963-06-30   8756.000000  1963.0   7902.666667
# 1963-09-30  10392.333333  1963.0  10286.000000
# 1963-12-31   7356.333333  1963.0   8335.000000
# 1964-03-31   7287.666667  1964.0   7023.666667

# %%
yearly_total_miles_df = miles_df.resample('A' , on="Month").sum()

# %%
yearly_total_miles_df.head()
# Out:
#             MilesMM   year      lag1
# Month
# 1963-12-31    99603  23556   92576.0
# 1964-12-31   106192  23568  105617.0
# 1965-12-31   115431  23580  115100.0
# 1966-12-31   119154  23592  117807.0
# 1967-12-31   126515  23604  126181.0

# %%
upsampled_miles_df = miles_df.resample('D'  ,on="Month").mean()

# %%
upsampled_miles_df.head(50)
# Out:
#             MilesMM    year    lag1
# Month
# 1963-01-01   6827.0  1963.0     NaN
# 1963-01-02      NaN     NaN     NaN
# 1963-01-03      NaN     NaN     NaN
# 1963-01-04      NaN     NaN     NaN
# 1963-01-05      NaN     NaN     NaN
# 1963-01-06      NaN     NaN     NaN
# 1963-01-07      NaN     NaN     NaN
# 1963-01-08      NaN     NaN     NaN
# 1963-01-09      NaN     NaN     NaN
# 1963-01-10      NaN     NaN     NaN
# 1963-01-11      NaN     NaN     NaN
# 1963-01-12      NaN     NaN     NaN
# 1963-01-13      NaN     NaN     NaN
# 1963-01-14      NaN     NaN     NaN
# 1963-01-15      NaN     NaN     NaN
# 1963-01-16      NaN     NaN     NaN
# 1963-01-17      NaN     NaN     NaN
# 1963-01-18      NaN     NaN     NaN
# 1963-01-19      NaN     NaN     NaN
# 1963-01-20      NaN     NaN     NaN
# 1963-01-21      NaN     NaN     NaN
# 1963-01-22      NaN     NaN     NaN
# 1963-01-23      NaN     NaN     NaN
# 1963-01-24      NaN     NaN     NaN
# 1963-01-25      NaN     NaN     NaN
# ...

# %%
interpolated_miles_df = upsampled_miles_df.interpolate(method = "linear")

# %%
interpolated_miles_df.head(50)
# Out:
#                 MilesMM    year         lag1
# Month
# 1963-01-01  6827.000000  1963.0          NaN
# 1963-01-02  6806.064516  1963.0          NaN
# 1963-01-03  6785.129032  1963.0          NaN
# 1963-01-04  6764.193548  1963.0          NaN
# 1963-01-05  6743.258065  1963.0          NaN
# 1963-01-06  6722.322581  1963.0          NaN
# 1963-01-07  6701.387097  1963.0          NaN
# 1963-01-08  6680.451613  1963.0          NaN
# 1963-01-09  6659.516129  1963.0          NaN
# 1963-01-10  6638.580645  1963.0          NaN
# 1963-01-11  6617.645161  1963.0          NaN
# 1963-01-12  6596.709677  1963.0          NaN
# 1963-01-13  6575.774194  1963.0          NaN
# 1963-01-14  6554.838710  1963.0          NaN
# 1963-01-15  6533.903226  1963.0          NaN
# 1963-01-16  6512.967742  1963.0          NaN
# 1963-01-17  6492.032258  1963.0          NaN
# 1963-01-18  6471.096774  1963.0          NaN
# 1963-01-19  6450.161290  1963.0          NaN
# 1963-01-20  6429.225806  1963.0          NaN
# ...

# %%
interpolated_miles_df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
poly_interpolated_miles_df = upsampled_miles_df.interpolate(method = "spline" , order=2)

# %%
poly_interpolated_miles_df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # DECOMPOSING TIME SERIES

# %% [markdown]
# ADDITIVE MODEL:
# y(t) = LEVEL + TREND + SEASONALITY + NOISE
#
# MULTIPLICATIVE MODEL:
# y(t) = LEVEL * TREND * SEASONALITY * NOISE

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
miles_decom_df = pd.read_csv("C:/Data Files/Time Series/us-airlines-monthly-aircraft-miles-flown.csv" , header=0 , parse_dates=[0])

# %%
miles_decom_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_decom_df.index = miles_decom_df["Month"]

# %%
result = seasonal_decompose(miles_decom_df["MilesMM"] , model="additive")

# %%
result.plot()

# %%
result2 = seasonal_decompose(miles_decom_df["MilesMM"] , model="multiplicative")

# %%
result2.plot()

# %% [markdown]
# # Differencing

# %%
miles_diff = pd.read_csv("C:/Data Files/Time Series/us-airlines-monthly-aircraft-miles-flown.csv" , header=0 , parse_dates=[0])

# %%
miles_diff.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_diff['lag1'] = miles_diff["MilesMM"].shift(1)

# %%
miles_diff["MilesMM_diff1"] = miles_diff["MilesMM"].diff(periods=1)

# %%
miles_diff.head()
# Out:
#        Month  MilesMM    lag1  MilesMM_diff1
# 0 1963-01-01     6827     NaN            NaN
# 1 1963-02-01     6178  6827.0         -649.0
# 2 1963-03-01     7084  6178.0          906.0
# 3 1963-04-01     8162  7084.0         1078.0
# 4 1963-05-01     8462  8162.0          300.0

# %%
miles_diff.index = miles_diff["Month"]
result_a = seasonal_decompose(miles_diff["MilesMM"] , model="additive")
result_a.plot()

# %%
miles_diff.index = miles_diff["Month"]
result_b = seasonal_decompose(miles_diff.iloc[1: , 3] , model="additive")
result_b.plot()

# %%
miles_diff["MilesMM_diff1"].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
miles_diff["MilesMM_diff12"] = miles_diff["MilesMM_diff1"].diff(periods=12)

# %%
miles_diff["MilesMM_diff12"].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
result_c = seasonal_decompose(miles_diff.iloc[13: , 4]  ,model ="additive")
result_c.plot()

# %% [markdown]
# # TEST TRAIN SPLIT

# %%
temp_df = pd.read_csv("C:/Data Files/Time Series/daily-min-temperatures.csv" ,header=0 ,parse_dates=[0])

# %%
temp_df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
temp_df.shape
# Out:
# (3650, 2)

# %%
temp_df.shape[0]
# Out:
# 3650

# %%
temp_df.tail()
# Out:
#            Date  Temp
# 3645 1990-12-27  14.0
# 3646 1990-12-28  13.6
# 3647 1990-12-29  13.5
# 3648 1990-12-30  15.7
# 3649 1990-12-31  13.0

# %%
train_size = int(temp_df.shape[0] * 0.8)
train_size
# Out:
# 2920

# %%
train = temp_df[0 : train_size]

# %%
test = temp_df[train_size:]

# %%
train.shape
# Out:
# (2920, 2)

# %%
test.shape
# Out:
# (730, 2)

# %% [markdown]
# # Persistance model / Naive model

# %%
temp_df['t'] = temp_df["Temp"].shift(1)

# %%
temp_df.head()
# Out:
#         Date  Temp     t
# 0 1981-01-01  20.7   NaN
# 1 1981-01-02  17.9  20.7
# 2 1981-01-03  18.8  17.9
# 3 1981-01-04  14.6  18.8
# 4 1981-01-05  15.8  14.6

# %%
train1 , test1 = temp_df[1:temp_df.shape[0] - 7] , temp_df[temp_df.shape[0] - 7:]

# %%
train1.head()
# Out:
#         Date  Temp     t
# 1 1981-01-02  17.9  20.7
# 2 1981-01-03  18.8  17.9
# 3 1981-01-04  14.6  18.8
# 4 1981-01-05  15.8  14.6
# 5 1981-01-06  15.8  15.8

# %%
train1_x , train1_y = train1['t'] , train1['Temp']
test1_x , test1_y = test1['t'] , test1['Temp']

# %% [markdown]
# #  WALK FOWARD VALIDATION

# %%
predictions = test1_x.copy()

# %%
print(predictions)
print(test1_y)
# Out:
# 3643    10.0
# 3644    12.9
# 3645    14.6
# 3646    14.0
# 3647    13.6
# 3648    13.5
# 3649    15.7
# Name: t, dtype: float64
# 3643    12.9
# 3644    14.6
# 3645    14.0
# 3646    13.6
# 3647    13.5
# 3648    15.7
# 3649    13.0
# Name: Temp, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test1_y , predictions)
mse
# Out:
# 3.4228571428571413

# %%
from matplotlib import pyplot

# %%
pyplot.plot(test1_y)
pyplot.plot(predictions , color="red")

# %% [markdown]
# # AUTO REGRESSION MODEL

# %%
df = pd.read_csv("C:/Data Files/Time Series/daily-min-temperatures.csv" ,header=0 ,parse_dates=[0])

# %%
train , test = df.Temp[1:df.shape[0]-7] , df.Temp[df.shape[0]-7 :]

# %%
train.head()
# Out:
# 1    17.9
# 2    18.8
# 3    14.6
# 4    15.8
# 5    15.8
# Name: Temp, dtype: float64

# %%
from statsmodels.tsa.ar_model import AR

# %%
model = AR(train)
model_fit = model.fit()
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
# ...

# %%
model_fit.k_ar
# Out:
# 29

# %%
model_fit.params
# Out:
# const       0.557544
# L1.Temp     0.588595
# L2.Temp    -0.090826
# L3.Temp     0.048262
# L4.Temp     0.040065
# L5.Temp     0.039302
# L6.Temp     0.025946
# L7.Temp     0.044668
# L8.Temp     0.012768
# L9.Temp     0.037436
# L10.Temp   -0.000812
# L11.Temp    0.004791
# L12.Temp    0.018473
# L13.Temp    0.026891
# L14.Temp    0.000576
# L15.Temp    0.024810
# L16.Temp    0.007403
# L17.Temp    0.009916
# L18.Temp    0.034160
# L19.Temp   -0.009120
# L20.Temp    0.024213
# L21.Temp    0.018787
# L22.Temp    0.012184
# L23.Temp   -0.018553
# L24.Temp   -0.001772
# L25.Temp    0.016732
# L26.Temp    0.019762
# L27.Temp    0.009832
# L28.Temp    0.006227
# L29.Temp   -0.001377
# dtype: float64

# %%
predictions = model_fit.predict(start=len(train) , end=len(train)+len(test)-1)

# %%
predictions
# Out:
# 3643    11.871275
# 3644    13.053794
# 3645    13.532591
# 3646    13.243126
# 3647    13.091438
# 3648    13.146989
# 3649    13.176153
# dtype: float64

# %%
predictions.iloc[0]
# Out:
# 11.871274847727827

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test1_y , predictions)
mse
# Out:
# 1.5015252310069953

# %%
pyplot.plot(test1_y)
pyplot.plot(predictions , color="red")

# %% [markdown]
# # IMPLEMENT WALK FORWARD

# %%
df = pd.read_csv("C:/Data Files/Time Series/daily-min-temperatures.csv" ,header=0 ,parse_dates=[0])

# %%
train , test = df.Temp[1:df.shape[0]-7], df.Temp[df.shape[0]-7:]

# %%
data = train
predict = []
for t in test:
    model = AR(data)
    model_fit = model.fit()
    y = model_fit.predict(start = len(data) , end=len(train)+len(test)-1)
    print(y.values[0])
    predict.append(y.values[0])
    data = np.append(data , t)
    data = pd.Series(data)
# Out:
# 11.871274847727827
# 13.660699943835194
# 14.353164144090158
# 13.430120791627012
# 13.374756477185127
# 13.479111299420502
# 14.767773018439868
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# ...

# %%
predict
# Out:
# [11.871274847727827,
#  13.660699943835194,
#  14.353164144090158,
#  13.430120791627012,
#  13.374756477185127,
#  13.479111299420502,
#  14.767773018439868]

# %%
mse1 = mean_squared_error(test.values , predict)
mse1
# Out:
# 1.4524568425185358

# %%
pyplot.plot(test.values)
pyplot.plot(predict , color="yellow")

# %% [markdown]
# # MOVING AVERAGE MODEL

# %%
df = pd.read_csv("C:/Data Files/Time Series/daily-min-temperatures.csv" ,header=0 ,parse_dates=[0])

# %%
df['t'] = df['Temp'].shift(1)

# %%
df["Resid"] = df["Temp"] - df['t']

# %%
df.head()
# Out:
#         Date  Temp     t  Resid
# 0 1981-01-01  20.7   NaN    NaN
# 1 1981-01-02  17.9  20.7   -2.8
# 2 1981-01-03  18.8  17.9    0.9
# 3 1981-01-04  14.6  18.8   -4.2
# 4 1981-01-05  15.8  14.6    1.2

# %%
train , test = df.Resid[1:df.shape[0]-7] , df.Resid[df.shape[0]-7:]

# %%
train.head()
# Out:
# 1   -2.8
# 2    0.9
# 3   -4.2
# 4    1.2
# 5    0.0
# Name: Resid, dtype: float64

# %%
from statsmodels.tsa.ar_model import AR

# %%
model = AR(train)
model_fit = model.fit()
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\ar_model.py:791: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
# ...

# %%
model_fit.k_ar
# Out:
# 29

# %%
model_fit.params
# Out:
# const       -0.006415
# L1.Resid    -0.407139
# L2.Resid    -0.496194
# L3.Resid    -0.445747
# L4.Resid    -0.403706
# L5.Resid    -0.362528
# L6.Resid    -0.334810
# L7.Resid    -0.288468
# L8.Resid    -0.274281
# L9.Resid    -0.235333
# L10.Resid   -0.234799
# L11.Resid   -0.228532
# L12.Resid   -0.208608
# L13.Resid   -0.180324
# L14.Resid   -0.178425
# L15.Resid   -0.152265
# L16.Resid   -0.143617
# L17.Resid   -0.132501
# L18.Resid   -0.097075
# L19.Resid   -0.104927
# L20.Resid   -0.079371
# L21.Resid   -0.059348
# L22.Resid   -0.045921
# L23.Resid   -0.063197
# L24.Resid   -0.063441
# L25.Resid   -0.045061
# L26.Resid   -0.023578
# L27.Resid   -0.011882
# L28.Resid   -0.003789
# L29.Resid   -0.003422
# dtype: float64

# %%
pred_resid = model_fit.predict(start=len(train) , end=len(train)+len(test)-1)

# %%
pred_resid
# Out:
# 3643    2.004986
# 3644    1.264192
# 3645    0.510869
# 3646   -0.251687
# 3647   -0.122054
# 3648    0.077509
# 3649    0.055600
# dtype: float64

# %%
df.t[df.shape[0]-7:]
# Out:
# 3643    10.0
# 3644    12.9
# 3645    14.6
# 3646    14.0
# 3647    13.6
# 3648    13.5
# 3649    15.7
# Name: t, dtype: float64

# %%
predictions = df.t[df.shape[0]-7:] + pred_resid

# %%
predictions
# Out:
# 3643    12.004986
# 3644    14.164192
# 3645    15.110869
# 3646    13.748313
# 3647    13.477946
# 3648    13.577509
# 3649    15.755600
# dtype: float64

# %%
mse2 = mean_squared_error(test1_y , predictions)
mse2
# Out:
# 2.049398556648207

# %%
pyplot.plot(test1_y)
pyplot.plot(predictions , color="orange")

# %% [markdown]
# # ARIMA MODEL

# %%
df = pd.read_csv("C:/Data Files/Time Series/shampoo.csv" , header=0 , parse_dates=[0])

# %%
df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
df["Sales"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# trend is quadratic , d=2

# %% [markdown]
# ### AUTO-CORRELATION

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df["Sales"])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# where the autocorrelation plot is crossing confidence interval line , here q=5(MOVING AVERAGE)

# %% [markdown]
# ### PARTIAL AUTO-CORRELATION

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df["Sales"] , lags=15)

# %% [markdown]
# confidence interval b/w 2 and 3 , so p=2(AUTOREGRESSION)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df["Sales"] , order=(4,2,2))
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
model_fit = model.fit()
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
# ...

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D2.Sales   No. Observations:                   34
# Model:                 ARIMA(4, 2, 2)   Log Likelihood                -188.542
# Method:                       css-mle   S.D. of innovations             49.647
# Date:                Tue, 09 Feb 2021   AIC                            393.083
# Time:                        15:08:59   BIC                            405.294
# Sample:                             2   HQIC                           397.247
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.9197      0.096      9.597      0.000       0.732       1.108
# ar.L1.D2.Sales    -0.6086      0.196     -3.107      0.002      -0.992      -0.225
# ...

# %%
residuals = model_fit.resid

# %%
residuals.plot()
# Out:
# <AxesSubplot:>

# %%
residuals.describe()
# Out:
# count     34.000000
# mean       8.408990
# std       65.940957
# min     -109.296536
# 25%      -41.482084
# 50%        0.896237
# 75%       62.660390
# max      156.380273
# dtype: float64

# %%
output = model_fit.forecast()

# %%
output
# Out:
# (array([612.89883585]),
#  array([49.64682414]),
#  array([[515.59284859, 710.20482311]]))

# %%
model_fit.forecast(5)
# Out:
# (array([612.89883585, 686.60348518, 676.04726133, 727.38850681,
#         748.64409005]),
#  array([49.64682414, 58.11837543, 59.13504898, 60.28366637, 60.44679581]),
#  array([[515.59284859, 710.20482311],
#         [572.69356249, 800.51340787],
#         [560.14469509, 791.94982756],
#         [609.23469186, 845.54232175],
#         [630.17054729, 867.11763282]]))

# %% [markdown]
# ### WALK FORWARD WITH ARIMA

# %%
train_size = int(df.shape[0]*0.7)

# %%
train , test = df.Sales[0:train_size] , df.Sales[train_size:]

# %%
train.shape
# Out:
# (25,)

# %%
test.shape
# Out:
# (11,)

# %%
data=train
predict=[]
for t in test:
    model = ARIMA(data , order=(5,1,0))
    model_fit = model.fit()
    y = model_fit.forecast()
    print(y[0][0])
    predict.append(y[0][0])
    data = np.append(data , t)
    data = pd.Series(data)
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# 387.37635502672316
# 348.1542240654271
# 386.3087356400106
# 356.08213522421937
# 446.37949921543714
# ...

# %%
predict
# Out:
# [387.37635502672316,
#  348.1542240654271,
#  386.3087356400106,
#  356.08213522421937,
#  446.37949921543714,
#  394.7373195755154,
#  434.9155186041352,
#  507.9233369245273,
#  435.4829759326345,
#  652.7437939296194,
#  546.343410329999]

# %%
mse3 = mean_squared_error(test.values , predict)
mse3
# Out:
# 8119.128212443171

# %% [markdown]
# # SARIMA - Seasonal ARIMA

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_csv("C:/Data Files/Time Series/us-airlines-monthly-aircraft-miles-flown.csv" , header=0 , parse_dates=[0])

# %%
df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
df.tail()
# Out:
#         Month  MilesMM
# 91 1970-08-01    14057
# 92 1970-09-01    16234
# 93 1970-10-01    12389
# 94 1970-11-01    11595
# 95 1970-12-01    12772

# %%
df.index = df["Month"]

# %%
result_x = seasonal_decompose(df["MilesMM"] , model="multiplicative")

# %%
result_x.plot()

# %%
model = SARIMAX(df["MilesMM"] , order=(5,1,3) , seasonal_order = (1,1,1,12))
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit()
# Out:
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\rajpoot\.conda\envs\gputest\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
residuals = model_fit.resid

# %%
residuals.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
output = model_fit.forecast()

# %%
output
# Out:
# 1971-01-01    11476.000788
# Freq: MS, dtype: float64

# %%
model_fit.forecast(12)
# Out:
# 1971-01-01    11476.000788
# 1971-02-01    11153.739113
# 1971-03-01    13670.158786
# 1971-04-01    12648.006632
# 1971-05-01    14338.913895
# 1971-06-01    15786.366118
# 1971-07-01    14979.451132
# 1971-08-01    15362.649708
# 1971-09-01    16963.089291
# 1971-10-01    13681.987053
# 1971-11-01    12426.872790
# 1971-12-01    13730.460296
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
yhat = model_fit.predict()

# %%
yhat.head()
# Out:
# 1963-01-01       0.000000
# 1963-02-01    5871.800077
# 1963-03-01    5421.975095
# 1963-04-01    7122.209703
# 1963-05-01    7067.882532
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
pyplot.plot(df["MilesMM"])
pyplot.plot(yhat , color="violet")
