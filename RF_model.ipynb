# %%
import pandas as pd

df = pd.read_csv('vedika1.csv')

# %%
df.head()
# Out:
#    SI No  Member No  Age  Gender Marital status  \
# 0      1  100022221   18  Female        Married
# 1      2  170022804   18  Female        Married
# 2      3  220022202   18  Female        Married
# 3      4  220022758   18  Female        Married
# 4      5  280022111   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0           15900                             Non-Farm          CONSTRUCTOR
# 1           15000                                 FARM                DAIRY
# 2           19630                             Non-Farm               TAILOR
# 3           12000                                 FARM              BUFFALO
# 4           15000                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# 2                                    1                     4
# 3                                    1                     4
# 4                                    1                     4
#
#   Spouse Employment  status - Employed/unemployed  \
# 0                                   Self Employee
# 1                                   Self Employee
# 2                                   Self Employee
# 3                                   Self Employee
# 4                                   Self Employee
#
#    Amount of Arrear (Non-Repayment)   No of dependent family members  \
# 0                                0.0                               3
# 1                             1668.0                               3
# 2                                0.0                               3
# 3                             5028.0                               3
# 4                                0.0                               3
#
#    Amount of credit Purpose of credit Duration of credit  Rate of Interest  \
# 0             29800          CENTRING          18 Months            0.2484
# 1             29600          BUFFELOW          18 Months            0.2574
# 2             29800         TAILORING          18 Months            0.2484
# 3             29800           BUFFALO          18 Months            0.2484
# 4             29800      KIRANA STORE          18 Months            0.2484
#
#   Paid /Non Paid (Default)
# 0                     Paid
# 1         Non Paid Default
# 2                     Paid
# 3         Non Paid Default
# 4                     Paid

# %%
C = ['Age','Educational level - literate/Illiterate','Amount of credit']
X = pd.DataFrame()
for c in C:
    X[c] = df[c]
X.head()
# Out:
#    Age Educational level - literate/Illiterate  Amount of credit
# 0   18                               Literate              29800
# 1   18                             Illiterate              29600
# 2   18                             Illiterate              29800
# 3   18                             Illiterate              29800
# 4   18                               Literate              29800

# %%
y = df['Paid /Non Paid (Default)']

# %%
X = pd.get_dummies(X,drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8059, 3)
# (2687, 3)
# (8059,)
# (2687,)

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
X_test.head()
# Out:
#        Age  Amount of credit  \
# 10250   52             29600
# 406     22             29800
# 2221    28             29800
# 4741    34             29600
# 7608    42             29800
#
#        Educational level - literate/Illiterate_Literate
# 10250                                                  0
# 406                                                    0
# 2221                                                   1
# 4741                                                   0
# 7608                                                   0

# %%
y_pred = forest.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7830294008187569

# %% [markdown]
# Accuracy score of model - 78.30%
